# %% [markdown]
# # Task 1.1 Core Contribution / Architecture (8 marks)
#
# ## Step-by-Step Method Description
#
# *   **Step 1:** Initialize weights
#     *   Initialize the weight vector to zero.
#     *   Reference: Algorithm 1, "initialize weights $w^j \leftarrow 0$"
#     *   Purpose: Start learning from a blank state.
# *   **Step 2:** Acquire example
#     *   Acquire an unlabeled example $x$ from oracle $\mathcal{O}$.
#     *   Reference: Algorithm 1, Step 1.
#     *   Purpose: Get the next example from the online stream.
# *   **Step 3:** Compute prediction
#     *   Compute prediction $\hat{y} = \sum_j w^j x^j$.
#     *   Reference: Algorithm 1, Step 3.
#     *   Purpose: Make a prediction for the current example using existing weights.
# *   **Step 4:** Acquire label and perform standard gradient descant update
#     *   Acquire the true label $y$ and compute the standard unregularized gradient descent update using a scaling factor $\eta$: $w^j \leftarrow w^j + 2\eta (y - \hat{y}) x^j$.
#     *   Reference: Algorithm 1, Step 4 & 5.
#     *   Purpose: Adjust weights to reduce loss on the current example.
# *   **Step 5:** Truncated Gradient Sparsification
#     *   Apply the truncation function $T_1$ to the weights using gravity parameter $g_i$ and threshold $	heta$. Specifically, shrink the positive weights by $g_i\eta$ towards zero (bounded at 0 if $\le 	heta$), and negative weights by $g_i\eta$ towards zero (bounded at 0 if $\ge -	heta$).
#     *   Reference: Algorithm 1, Step 2. Equation (6).
#     *   Purpose: Shrink small coefficients exactly to zero to induce sparsity, achieving an online $L_1$ regularization effect efficiently.
#
# ## Final Summary Sentence
#
# *   **What problem this paper solves:** This paper solves the problem of performing online learning over large-scale, high-dimensional datasets where traditional batch $L_1$ regularization is computationally inefficient and standard online gradient descent fails to produce sparse feature weights.
# *   **What the authors claim makes their approach better than existing alternatives:** The authors claim their truncated gradient method achieves a continuous, theoretically sound, and aggressive sparsification of feature weights with only $O(k)$ time complexity per step (independent of total feature dimension $d$), while maintaining competitive prediction performance compared to dense stochastic gradient descent.
